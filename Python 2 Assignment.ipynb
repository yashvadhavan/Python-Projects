# %%
a= "My NaMe iS YasH VadHavAn"
print(a.upper())
print(a.lower())
print(a.title())
print(a.capitalize())
# Out:
# MY NAME IS YASH VADHAVAN
# my name is yash vadhavan
# My Name Is Yash Vadhavan
# My name is yash vadhavan

# %%
N= "Rohan"
print("Hello",N,"Welcome to Python Programming")
# Out:
# Hello Rohan Welcome to Python Programming

# %%
c = "Yash Vadhavan"
len(c)
# Out:
# 13

# %%
c[0:4:]
# Out:
# 'Yash'

# %%
c[5:13:]
# Out:
# 'Vadhavan'

# %%
q = (' "You are never too old to set another goal or dream a new dream" ')

# %%
print(q)
# Out:
#  "You are never too old to set another goal or dream a new dream"

# %%
print(" \"You are never too old to set another goal or dream a new dream\"")
# Out:
#  "You are never too old to set another goal or dream a new dream"

# %%
s = {10,20,30}
l = {40,50,60}

# %%
s.update(l)
print(s)
# Out:
# {50, 20, 40, 10, 60, 30}

# %%
s = "Yash is learning python"

# %%
print('python' in s)
# Out:
# True

# %%
print('learn' in s)
# Out:
# True

# %%
a = input("Enter Your Name - ")

print("Hello" ,a, "how are you today?")
# Out:
# Enter Your Name -  Yash
# Hello Yash how are you today?

# %%
b = input("Enter your age :")

print("You are",b,"years old")
# Out:
# Enter your age : 24
# You are 24 years old

# %%
c = float(input("Enter firts number-"))
d= float(input("Entter Second Number"))
Sum = (c+d)
Difference = (c-d)
Product = (c*d)
Quoteint = (c/d)
print(Sum,"\n",Difference,"\n",Product,"\n",Quoteint)
# Out:
# Enter firts number- 15
# Entter Second Number 2
# 17.0
#  13.0
#  30.0
#  7.5

# %%
S = input("Enter any sentence")
print(S)
# Out:
# Enter any sentence [I, am, Learning, Python]
# [I, am, Learning, Python]

# %%
S= ["Apple","Cat","Banana","Dog"]
print(S)
# Out:
# ['Apple', 'Cat', 'Banana', 'Dog']

# %%
S.sort(reverse = True)
print(S)
# Out:
# ['Dog', 'Cat', 'Banana', 'Apple']

# %%
C = input("What is your favoutie colour")
print(' "WOW ',C, ' is a favourite colour" ')
# Out:
# What is your favoutie colour Red
#  "WOW  Red  is a favourite colour"

# %%
Num = float(input("Enter any number"))
print(Num > 50)
# Out:
# Enter any number 100
# True

# %%
N = float(input("Enter any number"))
print(N%2 == 0)
# Out:
# Enter any number 19
# False

# %%
Age = float(input("Enter your age"))
print(Age >= 18)
# Out:
# Enter your age 17
# False

# %%
F = float(input("First Number is - "))
S = float(input("Second Number is - "))
print(F > S)
# Out:
# First Number is -  20
# Second Number is -  40
# False

# %%
W = input("Enter any word")
print(len(W) >= 5)
# Out:
# Enter any word Yash
# False

# %%
W = input("Enter any word")
print(len(W) >= 5)
# Out:
# Enter any word Rahul
# True

# %%
Password = input("Enter your password")
Has_minimun_length = (len(Password) >= 8)
contains_special_charaacter = '@' in Password or '#' in Password
print(Has_minimun_length and contains_special_charaacter)
# Out:
# Enter your password Yashvad0
# False

# %%
P = input("Enter you password : ")
L = (len(P) >=8)
S= "@" in P or "#" in P
print(L and S)
# Out:
# Enter you password :  Ilovemykanpur1@#
# True
