# %%
A = "What is Your Name"
B = "My Name is Yash Vadhavan"
print(A)
print(B)
# Out:
# What is Your Name
# My Name is Yash Vadhavan

# %%
C = B
print(C)
# Out:
# My Name is Yash Vadhavan

# %%
Name = "Yash"
print("Hello",Name,"would you like to learn some Python today")
# Out:
# Hello Yash would you like to learn some Python today

# %%
Quote = "Our doubts are traitors, and make us lose the good we oft might win, by fearing to attempt!"
Author_Name = "William Shakespeare"
print(Author_Name,"Once Said",Quote)
# Out:
# William Shakespeare Once Said Our doubts are traitors, and make us lose the good we oft might win, by fearing to attempt!

# %%
Famous_Person = input("What is Your Favourite Person -")
# Out:
# What is Your Favourite Person - William Shakespeare

# %%
message = (Famous_Person,"once said",Quote)
print(message)
# Out:
# ('William Shakespeare', 'once said', 'Our doubts are traitors, and make us lose the good we oft might win, by fearing to attempt!')

# %%
Add = (5+3)
Sub = (10-2)
M = (4*2)
D = (16/2)

# %%
print(Add)
print(Sub)
print(M)
print(D)
# Out:
# 8
# 8
# 8
# 8.0

# %%
Favourite_Number = input("My Favourite Number is -")
print(Favourite_Number)
# Out:
# My Favourite Number is - 04/12/200
# 04/12/200

# %%
name = "Yash"
Date = "25-9-2025"

# %%
print("My name is",name,"and the current date is",Date)
# Out:
# My name is Yash and the current date is 25-9-2025

# %%
names = ("Rahul","Yash","Vijay","Raghav","Aman")
print(names)
# Out:
# ('Rahul', 'Yash', 'Vijay', 'Raghav', 'Aman')

# %%
names[0]
# Out:
# 'Rahul'

# %%
names[1]
# Out:
# 'Yash'

# %%
names[2]
# Out:
# 'Vijay'

# %%
names[3]
# Out:
# 'Raghav'

# %%
names[4]
# Out:
# 'Aman'

# %%
print("Hello Mr.",names[0],"I hope you are doing well",names[1],"is calling you today for learning python with ",names[2],names[3],"and",names[4])
# Out:
# Hello Mr. Rahul I hope you are doing well Yash is calling you today for learning python with  Vijay Raghav and Aman

# %%
l= ("BMW Car", "Honda Bike", "Flight")
print(l)
# Out:
# ('BMW Car', 'Honda Bike', 'Flight')

# %%
print("I would like to buy a ",l[0])
# Out:
# I would like to buy a  BMW Car

# %%
print("I love to ride on my",l[1])
# Out:
# I love to ride on my Honda Bike
